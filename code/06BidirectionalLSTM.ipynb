# %%
# import libraries

# keras

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# basic

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# preprocessing, model selection and scores

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# nlp

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %matplotlib inline

# %%
# read in the data

data = pd.read_csv('../data/cleaned/labeled.csv')

# %%
# select only lemmatized column and label

df = data[['lemmatized', 'label']]

# %%
# set up X and y

X = df['lemmatized']
y = df['label']

# train test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state = 2020)

# %% [markdown]
# ### Preprocessing for modeling

# %%
# update stop_words for TF-IDF vectorizer

remove = ['-pron-', 'feel', 'know', 'want', 'life', 'go', 'think', 'make', 'people', 'really', 'even', 'much', 'now', 
          'pron', 'don', 'will', 'try', 'talk', 'friends', 'tell', 'just', 'like', 'time', 'want', 'well', 'thing', 'day',
          'friend', 'help', 'year', 'bad', 've', 'say', 'good', 'need', 'way', 'right', 'month', 'amp', 'x200b']

my_stop_words = text.ENGLISH_STOP_WORDS.union(remove)

# %%
# instantiate Tf-IDF

tvec = TfidfVectorizer(stop_words = my_stop_words, max_df = .80, min_df = 10, max_features = 256, ngram_range = (1, 1))

# %%
# fit/transform X then save it to a dataframe

train = tvec.fit_transform(X_train).toarray()
print(train.shape)

test = tvec.transform(X_test).toarray()
print(test.shape)
# Out:
# (71425, 256)
# (30612, 256)

# %%
train[0].shape
# Out:
# (256,)

# %%
# reshape to fit

train = train.reshape(train.shape[0], 1, train.shape[-1])
test = test.reshape(test.shape[0], 1, test.shape[-1])

# %%
train[0].shape
# Out:
# (1, 256)

# %% [markdown]
# ## Model 1 - Bidirectional LSTM

# %%
# instantiate sequential model

model_1 = Sequential()

# add layers

model_1.add(Bidirectional(LSTM(32, return_sequences = False), input_shape = (1, 256)))

model_1.add(Dense(32,
                  activation = 'relu'))

model_1.add(Dense(1,
                  activation = 'sigmoid'))

# compile

model_1.compile(loss = 'bce',
                optimizer = 'adam',
                metrics = ['acc'])

# check the model summary

model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 64)                73984
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 76,097
# Trainable params: 76,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit

batch = 256
num_epochs = 25

history_1 = model_1.fit(train, y_train,
                        batch_size = batch,
                        epochs = num_epochs, 
                        validation_data = (test, y_test))
# Out:
# Epoch 1/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.4496 - acc: 0.8091 - val_loss: 0.4040 - val_acc: 0.8202
# Epoch 2/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3977 - acc: 0.8233 - val_loss: 0.3994 - val_acc: 0.8209
# Epoch 3/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3947 - acc: 0.8244 - val_loss: 0.3989 - val_acc: 0.8200
# Epoch 4/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3927 - acc: 0.8257 - val_loss: 0.3977 - val_acc: 0.8226
# Epoch 5/25
# 280/280 [==============================] - 1s 2ms/step - loss: 0.3925 - acc: 0.8263 - val_loss: 0.3964 - val_acc: 0.8238
# Epoch 6/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3895 - acc: 0.8266 - val_loss: 0.3954 - val_acc: 0.8226
# Epoch 7/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3878 - acc: 0.8280 - val_loss: 0.3946 - val_acc: 0.8234
# Epoch 8/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3864 - acc: 0.8289 - val_loss: 0.3936 - val_acc: 0.8247
# Epoch 9/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3843 - acc: 0.8300 - val_loss: 0.3959 - val_acc: 0.8207
# Epoch 10/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3830 - acc: 0.8310 - val_loss: 0.3919 - val_acc: 0.8253
# Epoch 11/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3798 - acc: 0.8327 - val_loss: 0.3900 - val_acc: 0.8252
# Epoch 12/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3765 - acc: 0.8342 - val_loss: 0.3886 - val_acc: 0.8273
# Epoch 13/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3728 - acc: 0.8362 - val_loss: 0.3859 - val_acc: 0.8290
# Epoch 14/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3692 - acc: 0.8378 - val_loss: 0.3834 - val_acc: 0.8297
# Epoch 15/25
# 280/280 [==============================] - 1s 2ms/step - loss: 0.3628 - acc: 0.8409 - val_loss: 0.3812 - val_acc: 0.8324
# Epoch 16/25
# 280/280 [==============================] - 1s 2ms/step - loss: 0.3571 - acc: 0.8444 - val_loss: 0.3787 - val_acc: 0.8329
# Epoch 17/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3491 - acc: 0.8474 - val_loss: 0.3777 - val_acc: 0.8333
# Epoch 18/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3390 - acc: 0.8533 - val_loss: 0.3769 - val_acc: 0.8355
# Epoch 19/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3298 - acc: 0.8584 - val_loss: 0.3785 - val_acc: 0.8359
# Epoch 20/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3223 - acc: 0.8608 - val_loss: 0.3764 - val_acc: 0.8338
# Epoch 21/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3139 - acc: 0.8657 - val_loss: 0.3841 - val_acc: 0.8381
# Epoch 22/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.3098 - acc: 0.8679 - val_loss: 0.3785 - val_acc: 0.8354
# Epoch 23/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.2984 - acc: 0.8729 - val_loss: 0.3824 - val_acc: 0.8347
# Epoch 24/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.2934 - acc: 0.8752 - val_loss: 0.3861 - val_acc: 0.8350
# Epoch 25/25
# 280/280 [==============================] - 1s 3ms/step - loss: 0.2873 - acc: 0.8781 - val_loss: 0.3894 - val_acc: 0.8342

# %%
# plot losses and accuracies

def plots(history, which):   
    plt.figure(figsize = (8, 6))
    plt.plot(history.history[which], label = f'Train {which.title()}')
    plt.plot(history.history['val_' + which], label = f'Test {which.title()}')
    plt.xlabel('Epochs')
    plt.ylabel(which.title())
    plt.legend()
    plt.show()
    
    return

# %%
plots(history_1, 'loss')
plots(history_1, 'acc')

# %% [markdown]
# ## Model 2 - Bidirectional LSTM with Dropout

# %%
# instantiate sequential model

model_2 = Sequential()

# add layers

model_2.add(Bidirectional(LSTM(64, return_sequences = False), input_shape = (1, 256)))

model_2.add(Dense(64,
                  activation = 'relu'))

model_2.add(Dropout(0.5))

model_2.add(Dense(16,
                  activation = 'relu'))

model_2.add(Dense(1,
                  activation = 'sigmoid'))

# compile

model_2.compile(loss = 'bce',
                optimizer = 'adam',
                metrics = ['acc'])

# check the model summary

model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 173,665
# Trainable params: 173,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit

batch = 256
num_epochs = 25

history_2 = model_2.fit(train, y_train,
                        batch_size = batch,
                        epochs = num_epochs, 
                        validation_data = (test, y_test))
# Out:
# Epoch 1/25
# 280/280 [==============================] - 2s 6ms/step - loss: 0.4446 - acc: 0.8030 - val_loss: 0.4029 - val_acc: 0.8180
# Epoch 2/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.4009 - acc: 0.8231 - val_loss: 0.3998 - val_acc: 0.8220
# Epoch 3/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3968 - acc: 0.8243 - val_loss: 0.3975 - val_acc: 0.8223
# Epoch 4/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3946 - acc: 0.8252 - val_loss: 0.3957 - val_acc: 0.8230
# Epoch 5/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3918 - acc: 0.8266 - val_loss: 0.3944 - val_acc: 0.8229
# Epoch 6/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3902 - acc: 0.8271 - val_loss: 0.3934 - val_acc: 0.8237
# Epoch 7/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3864 - acc: 0.8299 - val_loss: 0.3917 - val_acc: 0.8244
# Epoch 8/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3826 - acc: 0.8319 - val_loss: 0.3910 - val_acc: 0.8255
# Epoch 9/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3804 - acc: 0.8319 - val_loss: 0.3888 - val_acc: 0.8259
# Epoch 10/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3762 - acc: 0.8347 - val_loss: 0.3875 - val_acc: 0.8272
# Epoch 11/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3710 - acc: 0.8377 - val_loss: 0.3864 - val_acc: 0.8272
# Epoch 12/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3657 - acc: 0.8403 - val_loss: 0.3832 - val_acc: 0.8303
# Epoch 13/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3597 - acc: 0.8434 - val_loss: 0.3808 - val_acc: 0.8324
# Epoch 14/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3518 - acc: 0.8481 - val_loss: 0.3792 - val_acc: 0.8337
# Epoch 15/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3402 - acc: 0.8528 - val_loss: 0.3842 - val_acc: 0.8294
# Epoch 16/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3329 - acc: 0.8573 - val_loss: 0.3779 - val_acc: 0.8362
# Epoch 17/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3270 - acc: 0.8605 - val_loss: 0.3801 - val_acc: 0.8355
# Epoch 18/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3117 - acc: 0.8663 - val_loss: 0.3941 - val_acc: 0.8375
# Epoch 19/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3038 - acc: 0.8702 - val_loss: 0.3910 - val_acc: 0.8269
# Epoch 20/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2901 - acc: 0.8770 - val_loss: 0.3998 - val_acc: 0.8374
# Epoch 21/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2823 - acc: 0.8793 - val_loss: 0.3913 - val_acc: 0.8340
# Epoch 22/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2728 - acc: 0.8853 - val_loss: 0.3988 - val_acc: 0.8296
# Epoch 23/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2647 - acc: 0.8890 - val_loss: 0.4127 - val_acc: 0.8334
# Epoch 24/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2564 - acc: 0.8927 - val_loss: 0.4144 - val_acc: 0.8284
# Epoch 25/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2483 - acc: 0.8949 - val_loss: 0.4197 - val_acc: 0.8260

# %%
# plot losses and accuracies

plots(history_2, 'loss')
plots(history_2, 'acc')

# %% [markdown]
# ## Model 3 - Bidirectional with LSTM: different neuron unit for first dense layer

# %%
# instantiate sequential model

model_3 = Sequential()

# add layers

model_3.add(Bidirectional(LSTM(64, return_sequences = False), input_shape = (1, 256)))

model_3.add(Dense(32,
                  activation = 'relu'))

model_3.add(Dropout(0.5))

model_3.add(Dense(16,
                  activation = 'relu'))

model_3.add(Dense(1,
                  activation = 'sigmoid'))

# compile

model_3.compile(loss = 'bce',
                optimizer = 'adam',
                metrics = ['acc'])

# check the model summary

model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 169,025
# Trainable params: 169,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit

batch = 256
num_epochs = 25

history_3 = model_3.fit(train, y_train,
                        batch_size = batch,
                        epochs = num_epochs, 
                        validation_data = (test, y_test))
# Out:
# Epoch 1/25
# 280/280 [==============================] - 2s 6ms/step - loss: 0.4474 - acc: 0.8024 - val_loss: 0.4037 - val_acc: 0.8196
# Epoch 2/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.4035 - acc: 0.8209 - val_loss: 0.3985 - val_acc: 0.8223
# Epoch 3/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3989 - acc: 0.8246 - val_loss: 0.3978 - val_acc: 0.8221
# Epoch 4/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3965 - acc: 0.8244 - val_loss: 0.3971 - val_acc: 0.8218
# Epoch 5/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3940 - acc: 0.8266 - val_loss: 0.3968 - val_acc: 0.8225
# Epoch 6/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3918 - acc: 0.8279 - val_loss: 0.3956 - val_acc: 0.8239
# Epoch 7/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3897 - acc: 0.8281 - val_loss: 0.3956 - val_acc: 0.8227
# Epoch 8/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3876 - acc: 0.8297 - val_loss: 0.3920 - val_acc: 0.8253
# Epoch 9/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3844 - acc: 0.8310 - val_loss: 0.3911 - val_acc: 0.8254
# Epoch 10/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3822 - acc: 0.8321 - val_loss: 0.3907 - val_acc: 0.8247
# Epoch 11/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3791 - acc: 0.8344 - val_loss: 0.3898 - val_acc: 0.8258
# Epoch 12/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3757 - acc: 0.8359 - val_loss: 0.3880 - val_acc: 0.8261
# Epoch 13/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3721 - acc: 0.8374 - val_loss: 0.3864 - val_acc: 0.8286
# Epoch 14/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3676 - acc: 0.8396 - val_loss: 0.3836 - val_acc: 0.8313
# Epoch 15/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3607 - acc: 0.8432 - val_loss: 0.3825 - val_acc: 0.8310
# Epoch 16/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3534 - acc: 0.8463 - val_loss: 0.3815 - val_acc: 0.8309
# Epoch 17/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3451 - acc: 0.8499 - val_loss: 0.3761 - val_acc: 0.8335
# Epoch 18/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3309 - acc: 0.8573 - val_loss: 0.3803 - val_acc: 0.8318
# Epoch 19/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3206 - acc: 0.8632 - val_loss: 0.3911 - val_acc: 0.8228
# Epoch 20/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3185 - acc: 0.8651 - val_loss: 0.3828 - val_acc: 0.8316
# Epoch 21/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3005 - acc: 0.8710 - val_loss: 0.3842 - val_acc: 0.8336
# Epoch 22/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.2893 - acc: 0.8766 - val_loss: 0.3944 - val_acc: 0.8344
# Epoch 23/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2811 - acc: 0.8790 - val_loss: 0.4015 - val_acc: 0.8355
# Epoch 24/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2740 - acc: 0.8827 - val_loss: 0.4091 - val_acc: 0.8277
# Epoch 25/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.2648 - acc: 0.8873 - val_loss: 0.4068 - val_acc: 0.8297

# %%
# plot losses and accuracies

plots(history_3, 'loss')
plots(history_3, 'acc')

# %% [markdown]
# ## Model 4 - with 2 dropouts

# %%
# instantiate sequential model

model_4 = Sequential()

# add layers

model_4.add(Bidirectional(LSTM(64, return_sequences = False), input_shape = (1, 256)))

model_4.add(Dropout(0.25))

model_4.add(Dense(32,
                  activation = 'relu'))

model_4.add(Dropout(0.25))

model_4.add(Dense(16,
                  activation = 'relu'))

model_4.add(Dense(1,
                  activation = 'sigmoid'))

# compile

model_4.compile(loss = 'bce',
                optimizer = 'adam',
                metrics = ['acc'])

# check the model summary

model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 169,025
# Trainable params: 169,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit

batch = 256
num_epochs = 25

history_4 = model_4.fit(train, y_train,
                        batch_size = batch,
                        epochs = num_epochs, 
                        validation_data = (test, y_test))
# Out:
# Epoch 1/25
# 280/280 [==============================] - 2s 6ms/step - loss: 0.4651 - acc: 0.8014 - val_loss: 0.4031 - val_acc: 0.8203
# Epoch 2/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.4001 - acc: 0.8235 - val_loss: 0.4022 - val_acc: 0.8189
# Epoch 3/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3969 - acc: 0.8254 - val_loss: 0.3981 - val_acc: 0.8218
# Epoch 4/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3950 - acc: 0.8261 - val_loss: 0.3971 - val_acc: 0.8220
# Epoch 5/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3928 - acc: 0.8269 - val_loss: 0.3967 - val_acc: 0.8213
# Epoch 6/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3918 - acc: 0.8265 - val_loss: 0.3965 - val_acc: 0.8212
# Epoch 7/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3908 - acc: 0.8281 - val_loss: 0.3956 - val_acc: 0.8220
# Epoch 8/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3891 - acc: 0.8286 - val_loss: 0.3959 - val_acc: 0.8227
# Epoch 9/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3879 - acc: 0.8293 - val_loss: 0.3945 - val_acc: 0.8219
# Epoch 10/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3867 - acc: 0.8307 - val_loss: 0.3937 - val_acc: 0.8226
# Epoch 11/25
# 280/280 [==============================] - 1s 4ms/step - loss: 0.3854 - acc: 0.8312 - val_loss: 0.3927 - val_acc: 0.8237
# Epoch 12/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3830 - acc: 0.8312 - val_loss: 0.3925 - val_acc: 0.8233
# Epoch 13/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3804 - acc: 0.8324 - val_loss: 0.3906 - val_acc: 0.8243
# Epoch 14/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3775 - acc: 0.8345 - val_loss: 0.3896 - val_acc: 0.8246
# Epoch 15/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3744 - acc: 0.8358 - val_loss: 0.3894 - val_acc: 0.8236
# Epoch 16/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3727 - acc: 0.8369 - val_loss: 0.3864 - val_acc: 0.8278
# Epoch 17/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3677 - acc: 0.8394 - val_loss: 0.3846 - val_acc: 0.8295
# Epoch 18/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3633 - acc: 0.8405 - val_loss: 0.3846 - val_acc: 0.8323
# Epoch 19/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3591 - acc: 0.8442 - val_loss: 0.3820 - val_acc: 0.8329
# Epoch 20/25
# 280/280 [==============================] - 1s 5ms/step - loss: 0.3529 - acc: 0.8460 - val_loss: 0.3815 - val_acc: 0.8300
# Epoch 21/25
# 280/280 [==============================] - 2s 5ms/step - loss: 0.3510 - acc: 0.8462 - val_loss: 0.3790 - val_acc: 0.8333
# Epoch 22/25
# 280/280 [==============================] - 2s 5ms/step - loss: 0.3436 - acc: 0.8508 - val_loss: 0.3800 - val_acc: 0.8344
# Epoch 23/25
# 280/280 [==============================] - 2s 6ms/step - loss: 0.3374 - acc: 0.8533 - val_loss: 0.3781 - val_acc: 0.8355
# Epoch 24/25
# 280/280 [==============================] - 2s 6ms/step - loss: 0.3344 - acc: 0.8557 - val_loss: 0.3790 - val_acc: 0.8359
# Epoch 25/25
# 280/280 [==============================] - 2s 6ms/step - loss: 0.3290 - acc: 0.8566 - val_loss: 0.3766 - val_acc: 0.8349

# %%
# plot losses and accuracies

plots(history_4, 'loss')
plots(history_4, 'acc')

# %% [markdown]
# ## Hyperparameter tuning

# %%
# create a function skeleton for tuning

def model_func(lstm_unit = 128, layer_one_neurons = 32, layer_two_neurons = 32, layer_one_dropout = 0.5, layer_two_dropout = 0.5):
    
    # instantiate the model
    model = Sequential()
    
    # add layers
    model.add(Bidirectional(LSTM(units = lstm_unit, return_sequences = False), input_shape = (1, 256)))
    model.add(Dense(units = layer_one_neurons, activation = 'relu'))
    model.add(Dropout(layer_one_dropout))
    model.add(Dense(units = layer_two_neurons, activation ='relu'))
    model.add(Dropout(layer_two_dropout))
    model.add(Dense(1, activation = 'sigmoid'))
    
    # compile
    model.compile(loss = 'bce', optimizer = 'adam', metrics = ['accuracy'])
    
    return model

# build the model

nn = KerasClassifier(build_fn = model_func, epochs = 10, batch_size = 512, verbose = 0)

# %%
# params grid

params = {
    'epochs':[20, 25],
    'batch_size': [128, 256],
    'lstm_unit': [128, 256],
    'layer_one_neurons': [16, 32],
    'layer_two_neurons': [16, 32],
    'layer_one_dropout': [0.25, 0.5],
    'layer_two_dropout': [0.25, 0.5]
}

# instantiate gridsearch

gs = GridSearchCV(estimator = nn, param_grid = params, cv = 3)

# fit

gs.fit(train, y_train)

print(f'Best score: {gs.best_score_}')
print(f'Best parameters: {gs.best_params_}')
# Out:
# Best score: 0.833195686340332
# Best parameters: {'batch_size': 256, 'epochs': 25, 'layer_one_dropout': 0.5, 'layer_one_neurons': 16, 'layer_two_dropout': 0.25, 'layer_two_neurons': 32, 'lstm_unit': 128}

# %% [markdown]
# ><font size = 4><font color = 'purple'>The score does not improve with different tuning methods.</font></font>
